# %% [markdown]
# Here are the various useful things:
# NOAA API: https://www.ncei.noaa.gov/access/paleo-search/api
#
# pyleoTUPS functions: https://github.com/LinkedEarth/PyleoTUPS/blob/main/pyleotups/core/Dataset.py

# %%
from pyleotups import Dataset
import pandas as pd
import numpy as np

# for plotting
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import matplotlib.gridspec as gridspec
import matplotlib.cm as cm
import matplotlib.colors as mcolors
from cartopy.io.shapereader import natural_earth, Reader
import matplotlib as mpl
import cartopy.io.shapereader as shpreader

# %%
# initiate 'dataset' object
ds = Dataset()

# %%
# only single studies allowed - this give an error
# ds.search_studies(noaa_id=[27490, 27490])

# %%
# this returns only the second value
# ds.search_studies(noaa_id=[27490 | 27491])

# %%
# so maybe I'd just have to loop through individual studies
ds.search_studies(noaa_id=27490)
# Out:
# Parsing NOAA studies: 100%|██████████████████████████████| 1/1 [00:00<?, ?it/s]
#   StudyID  XMLID                                          StudyName  \
# 0   27490  67635  Palmyra 860 Year Modern and Fossil Coral Oxyge...
#
#                    DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  CORALS AND SCLEROSPONGES             804               -56            1146
#
#    MostRecentYearCE                                         StudyNotes  \
# 0              2006  Monthly-resolved coral aragonite oxygen isotop...
#
#   ScienceKeywords                                      Investigators  \
# 0            None  R. Lawrence Edwards, Sylvia Dee, Kim Cobb, Jul...
#
#                                         Publications  \
# 0  [{'Author': 'Sylvia G. Dee, Kim M. Cobb, Julie...
#
#                                                Sites  \
# 0  [[{'DataTableID': '41697', 'DataTableName': 'P...
#
#                                              Funding
# 0  [{'fundingAgency': 'US National Science Founda...

# %%
# ok so it remembers the previous query?
ds.get_summary()
# Out:
#   StudyID  XMLID                                          StudyName  \
# 0   27490  67635  Palmyra 860 Year Modern and Fossil Coral Oxyge...
#
#                    DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  CORALS AND SCLEROSPONGES             804               -56            1146
#
#    MostRecentYearCE                                         StudyNotes  \
# 0              2006  Monthly-resolved coral aragonite oxygen isotop...
#
#   ScienceKeywords                                      Investigators  \
# 0            None  R. Lawrence Edwards, Sylvia Dee, Kim Cobb, Jul...
#
#                                         Publications  \
# 0  [{'Author': 'Sylvia G. Dee, Kim M. Cobb, Julie...
#
#                                                Sites  \
# 0  [[{'DataTableID': '41697', 'DataTableName': 'P...
#
#                                              Funding
# 0  [{'fundingAgency': 'US National Science Founda...

# %%
ds.search_studies(noaa_id=27491)
# Out:
# Parsing NOAA studies: 100%|██████████████████████████████| 1/1 [00:00<?, ?it/s]
#   StudyID  XMLID                                    StudyName   DataType  \
# 0   27491  67642  Manzanedo - Freiburg - FASY - ITRDB GERM224  TREE RING
#
#    EarliestYearBP  MostRecentYearBP  EarliestYearCE  MostRecentYearCE  \
# 0              51               -63            1899              2013
#
#                                           StudyNotes  \
# 0  NOAA Template Raw Measurements file added 2020...
#
#                                      ScienceKeywords  \
# 0  [Fagus sylvatica L., common beech, FASY, Europ...
#
#                                        Investigators  \
# 0  Rubén Manzanedo, Markus Fischer, Rafael Navarr...
#
#                                         Publications  \
# 0  [{'Author': 'Rubén D. Manzanedo, Markus Fische...
#
#                                                Sites Funding
# 0  [[{'DataTableID': '39913', 'DataTableName': 'G...      []

# %%
ds.get_summary()
# Out:
#   StudyID  XMLID                                    StudyName   DataType  \
# 0   27491  67642  Manzanedo - Freiburg - FASY - ITRDB GERM224  TREE RING
#
#    EarliestYearBP  MostRecentYearBP  EarliestYearCE  MostRecentYearCE  \
# 0              51               -63            1899              2013
#
#                                           StudyNotes  \
# 0  NOAA Template Raw Measurements file added 2020...
#
#                                      ScienceKeywords  \
# 0  [Fagus sylvatica L., common beech, FASY, Europ...
#
#                                        Investigators  \
# 0  Rubén Manzanedo, Markus Fischer, Rafael Navarr...
#
#                                         Publications  \
# 0  [{'Author': 'Rubén D. Manzanedo, Markus Fische...
#
#                                                Sites Funding
# 0  [[{'DataTableID': '39913', 'DataTableName': 'G...      []

# %% [markdown]
# ### let's look at studies in eastern Australia

# %%
# initialise a new dataset object
ds_aus = Dataset()

# %%
ds_aus.search_studies(max_lat=-20, min_lat=-35, max_lon=130, min_lon=120)
# Out:
# Parsing NOAA studies: 100%|██████████████████| 100/100 [00:00<00:00, 12801.17it/s]
#    StudyID  XMLID                                          StudyName  \
# 0    12203  10267  2000 Year Precipitation-Based Southern Oscilla...
# 1    22315  20388        2000 Year Tropical Rainfall Reconstructions
# 2    12894  10958  9400 Year Cosmogenic Isotope Data and Solar Ac...
# 3    12402  10446  A Bayesian ANOVA Scheme for Calculating Climat...
# 4     5783   2619  Ammann and Naveau 2003 Statistical Analysis of...
# ..     ...    ...                                                ...
# 95    5983   2681  Global Network for Isotopes in Precipitation(G...
# 96   31572  73252  Global Ocean 25,000 Year Atmosphere-Ocean CO2 ...
# 97   12423  10466        Global Ocean Glacial Export Production Data
# 98   31633  73292  Global Ocean Glacial Termination Radiocarbon M...
# 99   26851  65815  Global Ocean Last Interglacial Sea Surface Tem...
#
#                    DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0   CLIMATE RECONSTRUCTIONS          1900.0              -5.0            50.0
# 1   CLIMATE RECONSTRUCTIONS          2000.0             -50.0           -50.0
# 2           CLIMATE FORCING          9389.0             -27.0         -7439.0
# 3         OTHER COLLECTIONS           -11.0             -40.0          1961.0
# 4           CLIMATE FORCING           550.0             -48.0          1400.0
# ..                      ...             ...               ...             ...
# 95        OTHER COLLECTIONS            -7.0             -41.0          1957.0
# 96   PALEOCLIMATIC MODELING         25000.0               0.0        -23050.0
# 97         PALEOCEANOGRAPHY        100000.0           18000.0        -98050.0
# 98   PALEOCLIMATIC MODELING         25000.0           15000.0        -23050.0
# 99  CLIMATE RECONSTRUCTIONS        129000.0          116000.0       -127050.0
#
#     MostRecentYearCE                                         StudyNotes  \
# 0             1955.0  Reconstruction of a precipitation-based Southe...
# 1             2000.0  Composite reconstruction of low latitude rainf...
# 2             1977.0  Records of common production rate of cosmogeni...
# 3             1990.0  Matlab code for two-factor (location and year)...
# 4             1998.0                                               None
# ..               ...                                                ...
# 95            1991.0
# 96            1950.0  Transient simulation of ocean carbonate chemis...
# 97          -16050.0  Tables and Table Notes    \nTable S1. Change i...
# 98          -13050.0  Simulations with radiocarbon-dead DIC injected...
# 99         -114050.0  Compilation of published sea surface temperatu...
#
#                                       ScienceKeywords  \
# 0   [ENSO, Atmospheric and Oceanic Circulation Pat...
# 1                      [Precipitation Reconstruction]
# 2                      [Solar Forcing Reconstruction]
# 3                                                None
# 4                                                None
# ..                                                ...
# 95                                               None
# 96                                     [carbon cycle]
# 97                            [biogeochemical cycles]
# 98                                               None
# 99           [Sea Surface Temperature Reconstruction]
#
#                                         Investigators  \
# 0   Liguang Sun, Yuhong Wang, Wen Huang, Shican Qi...
# 1   Franziska Lechleitner, Sebastian Breitenbach, ...
# 2   Frank Wilhelms, Hans Oerter, Friedhelm Steinhi...
# 3                                      Martin Tingley
# 4                      Philippe Naveau, Caspar Ammann
# ..                                                ...
# 95  Kazimierz Rozanski, Luis Araguás-Araguás, Robe...
# 96  Jun Shao, Lowell Stott, William Gray, Rosanna ...
# 97  Karen Kohfeld, Corinne Le Quéré, Sandy Harriso...
# 98  Lowell Stott, Brian Davy, Ingo Pecher, Helen N...
# 99  Chris Turney, Zoë Thomas, Richard Jones, Nicho...
#
#                                          Publications  \
# 0   [{'Author': 'Yan, H., L. Sun, Y. Wang, W. Huan...
# 1   [{'Author': 'Franziska A. Lechleitner, Sebasti...
# 2   [{'Author': 'Steinhilber, F., J.A. Abreu, J. B...
# 3   [{'Author': 'Tingley, M.P.', 'Title': 'A Bayes...
# 4   [{'Author': 'Ammann, C.M. and P. Naveau', 'Tit...
# ..                                                ...
# 95                                                 []
# 96  [{'Author': 'Jun Shao, Lowell D. Stott, Willia...
# 97  [{'Author': 'Kohfeld, K.E., C. Le Quéré, S.P. ...
# 98  [{'Author': 'Lowell Stott, Bryan Davy, Jun Sha...
# 99  [{'Author': 'Chris S.M. Turney, Richard T. Jon...
#
#                                                 Sites  \
# 0   [[{'DataTableID': '20526', 'DataTableName': 'S...
# 1   [[{'DataTableID': '33444', 'DataTableName': 'L...
# 2   [[{'DataTableID': '21230', 'DataTableName': 'T...
# 3   [[{'DataTableID': '20755', 'DataTableName': 'A...
# 4   [[{'DataTableID': '38237', 'DataTableName': 'A...
# ..                                                ...
# 95  [[{'DataTableID': '32472', 'DataTableName': 'G...
# 96  [[{'DataTableID': '44097', 'DataTableName': 'S...
# 97  [[{'DataTableID': '20776', 'DataTableName': 'K...
# 98  [[{'DataTableID': '44120', 'DataTableName': 'S...
# 99  [[{'DataTableID': '39473', 'DataTableName': 'T...
#
#                                               Funding
# 0   [{'fundingAgency': 'National Natural Science F...
# 1   [{'fundingAgency': 'European Union', 'fundingG...
# 2   [{'fundingAgency': 'Swiss National Science Fou...
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 95                                                 []
# 96  [{'fundingAgency': 'US National Science Founda...
# 97                                                 []
# 98  [{'fundingAgency': 'US National Science Founda...
# 99                                                 []
#
# [100 rows x 14 columns]

# %%
# I'd also like to filter by type = "Climate Reconstructions"
ds_aus.search_studies(max_lat=-20, min_lat=-35, max_lon=130, min_lon=120, data_type_id=3)
# Out:
# Parsing NOAA studies: 100%|███████████████| 100/100 [00:00<00:00, 16625.59it/s]
#    StudyID  XMLID                                          StudyName  \
# 0    12203  10267  2000 Year Precipitation-Based Southern Oscilla...
# 1    22315  20388        2000 Year Tropical Rainfall Reconstructions
# 2    12894  10958  9400 Year Cosmogenic Isotope Data and Solar Ac...
# 3     8672   2746  Anderson and Archer 2002 Last Glacial Maximum ...
# 4    40399  81483  Antarctica Station Dome Concordia Chemistry, S...
# ..     ...    ...                                                ...
# 95   31652  73312  North Australia 246 Year Standardised Precipit...
# 96   28470  69030  Northwest Atlantic and Indo-Pacific Southern O...
# 97    6327   3330  Oerlemans 2005 Global Glacier Length Temperatu...
# 98   12621  10664                     PAGES (Past Global Changes) 2K
# 99   17955  15657  PAGES Ocean2K 400 Year Coral Data and Tropical...
#
#                     DataType  EarliestYearBP  MostRecentYearBP  \
# 0    CLIMATE RECONSTRUCTIONS          1900.0              -5.0
# 1    CLIMATE RECONSTRUCTIONS          2000.0             -50.0
# 2            CLIMATE FORCING          9389.0             -27.0
# 3           PALEOCEANOGRAPHY             NaN               NaN
# 4                  ICE CORES        346462.0             500.0
# ..                       ...             ...               ...
# 95   CLIMATE RECONSTRUCTIONS           188.0             -57.0
# 96          PALEOCEANOGRAPHY         33730.0            8981.0
# 97   CLIMATE RECONSTRUCTIONS           350.0              50.0
# 98   CLIMATE RECONSTRUCTIONS          1950.0             -62.0
# 99  CORALS AND SCLEROSPONGES           398.0             -57.0
#
#     EarliestYearCE  MostRecentYearCE  \
# 0             50.0            1955.0
# 1            -50.0            2000.0
# 2          -7439.0            1977.0
# 3              NaN               NaN
# 4        -344512.0            1450.0
# ..             ...               ...
# 95          1762.0            2007.0
# 96        -31780.0           -7031.0
# 97          1600.0            1900.0
# 98             0.0            2012.0
# 99          1552.0            2007.0
#
#                                            StudyNotes  \
# 0   Reconstruction of a precipitation-based Southe...
# 1   Composite reconstruction of low latitude rainf...
# 2   Records of common production rate of cosmogeni...
# 3
# 4   Provided Keywords: ocean heat content, mean oc...
# ..                                                ...
# 95  Reconstruction of the Standardised Precipitati...
# 96  Deep-sea coral radiocarbon and clumped-isotope...
# 97                                               None
# 98                                               None
# 99  This data set contains both the coral data and...
#
#                                       ScienceKeywords  \
# 0   [Atmospheric and Oceanic Circulation Patterns ...
# 1                      [Precipitation Reconstruction]
# 2                      [Solar Forcing Reconstruction]
# 3                                                None
# 4   [Last Interglacial, Glacial, Interglacial, mil...
# ..                                                ...
# 95                                          [drought]
# 96                                               None
# 97                   [Air Temperature Reconstruction]
# 98  [PAGES Antarctica 2k, PAGES Ocean 2k, PAGES Eu...
# 99  [PAGES Ocean 2k, Sea Surface Temperature Recon...
#
#                                         Investigators  \
# 0   Liguang Sun, Yuhong Wang, Wen Huang, Shican Qi...
# 1   Franziska Lechleitner, Sebastian Breitenbach, ...
# 2   Frank Wilhelms, Hans Oerter, Friedhelm Steinhi...
# 3                        David Archer, David Anderson
# 4   Markus Grimmer, Daniel Baggenstos, Jochen Schm...
# ..                                                ...
# 95  Katherine Allen, Mandy Freund, Jonathan Palmer...
# 96  Sophia Hines, John Eiler, John Southon, Jess A...
# 97                                 Johannes Oerlemans
# 98                              None PAGES 2k Network
# 99  Jessica Tierney, Nerilie Abram, Kevin Anchukai...
#
#                                          Publications  \
# 0   [{'Author': 'Yan, H., L. Sun, Y. Wang, W. Huan...
# 1   [{'Author': 'Franziska A. Lechleitner, Sebasti...
# 2   [{'Author': 'Steinhilber, F., J.A. Abreu, J. B...
# 3   [{'Author': 'Anderson, D.M., and D. Archer', '...
# 4   [{'Author': 'Grimmer, Markus; Baggenstos, Dani...
# ..                                                ...
# 95  [{'Author': 'K.J. Allen, M.B. Freund, J.G. Pal...
# 96  [{'Author': 'Hines, Sophia K.V., Eiler, John M...
# 97  [{'Author': 'Oerlemans, J.', 'Title': 'Extract...
# 98  [{'Author': 'PAGES 2k Network', 'Title': 'PAGE...
# 99  [{'Author': 'Jessica E. Tierney, Nerilie J. Ab...
#
#                                                 Sites  \
# 0   [[{'DataTableID': '20526', 'DataTableName': 'S...
# 1   [[{'DataTableID': '33444', 'DataTableName': 'L...
# 2   [[{'DataTableID': '21230', 'DataTableName': 'T...
# 3   [[{'DataTableID': 'Unspecified', 'DataTableNam...
# 4   [[{'DataTableID': '53967', 'DataTableName': 'E...
# ..                                                ...
# 95  [[{'DataTableID': '44157', 'DataTableName': 'A...
# 96  [[{'DataTableID': '40757', 'DataTableName': 'T...
# 97  [[{'DataTableID': '38617', 'DataTableName': 'O...
# 98  [[{'DataTableID': '30828', 'DataTableName': 'P...
# 99  [[{'DataTableID': '28454', 'DataTableName': 'T...
#
#                                               Funding
# 0   [{'fundingAgency': 'National Natural Science F...
# 1   [{'fundingAgency': 'European Union', 'fundingG...
# 2   [{'fundingAgency': 'Swiss National Science Fou...
# 3                                                  []
# 4   [{'fundingAgency': 'Swiss National Science Fou...
# ..                                                ...
# 95                                                 []
# 96  [{'fundingAgency': 'US National Science Founda...
# 97                                                 []
# 98                                                 []
# 99  [{'fundingAgency': 'PAGES (Past Global Changes...
#
# [100 rows x 14 columns]

# %%
# here are trees
ds_aus.search_studies(max_lat=-20, min_lat=-35, max_lon=130, min_lon=120, data_type_id=18)
# Out:
# Parsing NOAA studies: 100%|████████████████████| 12/12 [00:00<00:00, 12000.87it/s]
#    StudyID  XMLID                                          StudyName  \
# 0    22315  20388        2000 Year Tropical Rainfall Reconstructions
# 1     6224   2479  Briffa et al. 1998 Northern Hemisphere Tempera...
# 2    14188  12189  Continental-scale temperature variability duri...
# 3    23890  22034  Hemispheric 1,000 Year Pseudoproxy Data and Te...
# 4     6318   2719  Jansen et al. 2007 IPCC WG1 AR4 Palaeoclimate ...
# 5     6271   2451    Jones and Mann 2004 Climate Over Past Millennia
# 6     8407    674      NOAA Paleoclimatology Reconstructions Network
# 7    31652  73312  North Australia 246 Year Standardised Precipit...
# 8    19886  17759             Re-Standardized Tree-Ring Chronologies
# 9    13673  11695  Southern Annular Mode (SAM) Index 600 Year Tre...
# 10   16459  14185  Southern Oscillation Index 275 Year Reconstruc...
# 11   25570  23754  The International Tree-Ring Data Bank (ITRDB) ...
#
#                    DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0   CLIMATE RECONSTRUCTIONS            2000               -50             -50
# 1   CLIMATE RECONSTRUCTIONS             550               -44            1400
# 2   CLIMATE RECONSTRUCTIONS            1950               -50               0
# 3   CLIMATE RECONSTRUCTIONS             950               -50            1000
# 4   CLIMATE RECONSTRUCTIONS             950               -54            1000
# 5   CLIMATE RECONSTRUCTIONS            1750               -45             200
# 6   CLIMATE RECONSTRUCTIONS            1950               -50               0
# 7   CLIMATE RECONSTRUCTIONS             188               -57            1762
# 8                 TREE RING            1950               -50               0
# 9   CLIMATE RECONSTRUCTIONS             541               -57            1409
# 10  CLIMATE RECONSTRUCTIONS             251               -21            1699
# 11                TREE RING            7950               -65           -6000
#
#     MostRecentYearCE                                         StudyNotes  \
# 0               2000  Composite reconstruction of low latitude rainf...
# 1               1994  The data consists of two timeseries representa...
# 2               2000                                               None
# 3               2000  Pseudoproxy data and reconstruction outputs fo...
# 4               2004  Data From Chapter 6, Palaeoclimate, In Climate...
# 5               1995                                               None
# 6               2000  NOAA Paleoclimatology Paleoclimate Network (PC...
# 7               2007  Reconstruction of the Standardised Precipitati...
# 8               2000  Breitenmoser et al. 2014 Re-standardized  tree...
# 9               2007  Southern Annular Mode (SAM) Index reconstructi...
# 10              1971  Southern Oscillation Index (SOI) 275 year reco...
# 11              2015  Harmonized and corrected version of the ITRDB ...
#
#                                       ScienceKeywords  \
# 0                      [Precipitation Reconstruction]
# 1                    [Air Temperature Reconstruction]
# 2   [Little Ice Age (LIA), PAGES Arctic 2k, Mediev...
# 3                    [Air Temperature Reconstruction]
# 4                    [Air Temperature Reconstruction]
# 5   [Atmospheric and Oceanic Circulation Patterns ...
# 6                    [Air Temperature Reconstruction]
# 7                                           [drought]
# 8                                [Various taxa, MIXD]
# 9   [Atmospheric and Oceanic Circulation Patterns ...
# 10  [Atmospheric and Oceanic Circulation Patterns ...
# 11                                               None
#
#                                         Investigators  \
# 0   Franziska Lechleitner, Sebastian Breitenbach, ...
# 1   Keith Briffa, Philip Jones, Fritz Schweingrube...
# 2                               None PAGES 2k Network
# 3   Raphael Neukom, Andrew Schurer, Nathan Steiger...
# 4   Eystein Jansen, Jonathan Overpeck, Timothy Osb...
# 5                          Philip Jones, Michael Mann
# 6   Eugene Wahl, David Anderson, Bruce Bauer, Rodn...
# 7   Katherine Allen, Mandy Freund, Jonathan Palmer...
# 8   Petra Breitenmoser, Stefan Brönnimann, David F...
# 9   Antonio Lara, Mariano Masiokas, Roberto Urruti...
# 10                   David Stahle, Malcolm Cleaveland
# 11  Shoudong Zhao, Neil Pederson, Loïc D'Orangevil...
#
#                                          Publications  \
# 0   [{'Author': 'Franziska A. Lechleitner, Sebasti...
# 1   [{'Author': 'Briffa K.R., P.D. Jones, F.H. Sch...
# 2   [{'Author': 'PAGES 2k Consortium', 'Title': 'C...
# 3   [{'Author': 'Raphael Neukom, Andrew P. Schurer...
# 4                                                  []
# 5   [{'Author': 'Jones, P.D. and M.E. Mann', 'Titl...
# 6   [{'Author': 'Wahl, E.R., D.M. Anderson, B.A. B...
# 7   [{'Author': 'K.J. Allen, M.B. Freund, J.G. Pal...
# 8   [{'Author': 'Breitenmoser, P., Brönnimann, S.,...
# 9   [{'Author': 'Ricardo Villalba, Antonio Lara, M...
# 10  [{'Author': 'David W. Stahle and Malcolm K. Cl...
# 11  [{'Author': 'Shoudong Zhao, Neil Pederson, Loï...
#
#                                                 Sites  \
# 0   [[{'DataTableID': '33444', 'DataTableName': 'L...
# 1   [[{'DataTableID': '49391', 'DataTableName': 'v...
# 2   [[{'DataTableID': '32519', 'DataTableName': 'P...
# 3   [[{'DataTableID': '35833', 'DataTableName': 'N...
# 4   [[{'DataTableID': '38438', 'DataTableName': 'J...
# 5   [[{'DataTableID': '38374', 'DataTableName': 'J...
# 6   [[{'DataTableID': '20557', 'DataTableName': 'P...
# 7   [[{'DataTableID': '44157', 'DataTableName': 'A...
# 8   [[{'DataTableID': '30551', 'DataTableName': 'B...
# 9   [[{'DataTableID': '23354', 'DataTableName': 'V...
# 10  [[{'DataTableID': '26592', 'DataTableName': 'S...
# 11  [[{'DataTableID': '37493', 'DataTableName': 'Z...
#
#                                               Funding
# 0   [{'fundingAgency': 'European Union', 'fundingG...
# 1   [{'fundingAgency': 'Swiss National Science Fou...
# 2                                                  []
# 3                                                  []
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8   [{'fundingAgency': 'Swiss National Science Fou...
# 9   [{'fundingAgency': 'UK Natural Environment Res...
# 10                                                 []
# 11  [{'fundingAgency': 'National Science Foundatio...

# %%
# and lakes - surely there shold be more of these? 
ds_aus.search_studies(max_lat=-20, min_lat=-35, max_lon=130, min_lon=120, data_type_id=13)
# Out:
# Parsing NOAA studies: 100%|████████████████████| 6/6 [00:00<00:00, 4779.83it/s]
#   StudyID  XMLID                                          StudyName  \
# 0   12203  10267  2000 Year Precipitation-Based Southern Oscilla...
# 1   22315  20388        2000 Year Tropical Rainfall Reconstructions
# 2   20529  18345                 Global Holocene Paleodust Database
# 3    8407    674      NOAA Paleoclimatology Reconstructions Network
# 4   36134  77393  Paleo-pCO2 Database Global C3 Plant pCO2 Data ...
# 5    5800   2481  Viau and Gajewski 2001 Global Lake Level Statu...
#
#                   DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  CLIMATE RECONSTRUCTIONS          1900.0              -5.0            50.0
# 1  CLIMATE RECONSTRUCTIONS          2000.0             -50.0           -50.0
# 2       LOESS AND PALEOSOL         12000.0               0.0        -10050.0
# 3  CLIMATE RECONSTRUCTIONS          1950.0             -50.0             0.0
# 4          CLIMATE FORCING         30000.0             -65.0        -28050.0
# 5              LAKE LEVELS             NaN               NaN             NaN
#
#    MostRecentYearCE                                         StudyNotes  \
# 0            1955.0  Reconstruction of a precipitation-based Southe...
# 1            2000.0  Composite reconstruction of low latitude rainf...
# 2            1950.0  Mineral dust data (dust mass accumulation rate...
# 3            2000.0  NOAA Paleoclimatology Paleoclimate Network (PC...
# 4            2015.0                                               None
# 5               NaN                                               None
#
#                                      ScienceKeywords  \
# 0  [ENSO, Atmospheric and Oceanic Circulation Pat...
# 1                     [Precipitation Reconstruction]
# 2                                               None
# 3                   [Air Temperature Reconstruction]
# 4                                               None
# 5                                               None
#
#                                        Investigators  \
# 0  Liguang Sun, Yuhong Wang, Wen Huang, Shican Qi...
# 1  Franziska Lechleitner, Sebastian Breitenbach, ...
# 2                                      Samuel Albani
# 3  Eugene Wahl, David Anderson, Bruce Bauer, Rodn...
# 4                        Brian Schubert, Hope Jahren
# 5                        Andre Viau, Konrad Gajewski
#
#                                         Publications  \
# 0  [{'Author': 'Yan, H., L. Sun, Y. Wang, W. Huan...
# 1  [{'Author': 'Franziska A. Lechleitner, Sebasti...
# 2  [{'Author': 'S. Albani, N.M. Mahowald, G. Winc...
# 3  [{'Author': 'Wahl, E.R., D.M. Anderson, B.A. B...
# 4  [{'Author': 'Schubert, B. A., and Jahren, A. H...
# 5  [{'Author': 'Viau, A.E. and K. Gajewski', 'Tit...
#
#                                                Sites  \
# 0  [[{'DataTableID': '20526', 'DataTableName': 'S...
# 1  [[{'DataTableID': '33444', 'DataTableName': 'L...
# 2  [[{'DataTableID': '31279', 'DataTableName': 'A...
# 3  [[{'DataTableID': '20557', 'DataTableName': 'P...
# 4  [[{'DataTableID': '48778', 'DataTableName': 'c...
# 5  [[{'DataTableID': 'Unspecified', 'DataTableNam...
#
#                                              Funding
# 0  [{'fundingAgency': 'National Natural Science F...
# 1  [{'fundingAgency': 'European Union', 'fundingG...
# 2  [{'fundingAgency': 'US National Science Founda...
# 3                                                 []
# 4  [{'fundingAgency': 'US Department of Energy', ...
# 5                                                 []

# %%
# multiple archives
ds_aus.search_studies(max_lat=-20, min_lat=-35, max_lon=130, min_lon=120, data_type_id=4|7|13)
# Out:
# Parsing NOAA studies: 100%|██████████████████████████████| 6/6 [00:00<?, ?it/s]
#   StudyID  XMLID                                          StudyName  \
# 0    6249   2538  Farrera et al. 1999 LGM Tropical Terrestrial D...
# 1    5790   3325  McElwain and Chaloner 1995 Paleozoic Paleobota...
# 2   25910  64214      Paleo-pCO2 Database Cenozoic Stomata CO2 Data
# 3   23251  21455     Paleo-pCO2 Database Cenozoic Stomatal CO2 Data
# 4   36134  77393  Paleo-pCO2 Database Global C3 Plant pCO2 Data ...
# 5    5784   2643  Royer et al. 2001 Tertiary Paleobotanical Atmo...
#
#                   DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  CLIMATE RECONSTRUCTIONS         20000.0           16000.0        -18050.0
# 1          CLIMATE FORCING             NaN               NaN             NaN
# 2          CLIMATE FORCING      65900000.0        19000000.0     -65898050.0
# 3          CLIMATE FORCING      65400000.0        15200000.0     -65398050.0
# 4          CLIMATE FORCING         30000.0             -65.0        -28050.0
# 5          CLIMATE FORCING             NaN               NaN             NaN
#
#    MostRecentYearCE                                         StudyNotes  \
# 0          -14050.0
# 1               NaN
# 2       -18998050.0  Paleo-CO2 derived from fossil plant stomata, c...
# 3       -15198050.0  Paleo-CO2 data derived from fossil Ginkgo and ...
# 4            2015.0                                               None
# 5               NaN
#
#                                      ScienceKeywords  \
# 0  [Air Temperature Reconstruction, Other Hydrocl...
# 1                   [Atmospheric Gas Reconstruction]
# 2                                               None
# 3                                               None
# 4                                               None
# 5                   [Atmospheric Gas Reconstruction]
#
#                                        Investigators  \
# 0  Joël Guiot, Gilles Ramstein, Iain Prentice, Is...
# 1                William Chaloner, Jennifer McElwain
# 2                           Margret Steinthorsdottir
# 3                                         Dana Royer
# 4                        Brian Schubert, Hope Jahren
# 5  Leo Hickey, Dana Royer, Robert Berner, David B...
#
#                                         Publications  \
# 0  [{'Author': 'Farrera, I., Harrison, S.P., Pren...
# 1  [{'Author': 'McElwain, J.C. and W.G. Chaloner....
# 2  [{'Author': 'Margret Steinthorsdottir, Vivi Va...
# 3  [{'Author': 'Dana L. Royer, Scott L. Wing, Dav...
# 4  [{'Author': 'Schubert, B. A., and Jahren, A. H...
# 5  [{'Author': 'Dana L. Royer, Scott L. Wing, Dav...
#
#                                                Sites  \
# 0  [[{'DataTableID': '32505', 'DataTableName': 'F...
# 1  [[{'DataTableID': 'Unspecified', 'DataTableNam...
# 2  [[{'DataTableID': '37833', 'DataTableName': 'S...
# 3  [[{'DataTableID': '34814', 'DataTableName': 'R...
# 4  [[{'DataTableID': '48778', 'DataTableName': 'c...
# 5  [[{'DataTableID': 'Unspecified', 'DataTableNam...
#
#                                              Funding
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'fundingAgency': 'US Department of Energy', ...
# 5                                                 []

# %%
# tree
ds_aus.search_studies(noaa_id=25570)
# Out:
# Parsing NOAA studies: 100%|██████████████████████████████| 1/1 [00:00<?, ?it/s]
#   StudyID  XMLID                                          StudyName  \
# 0   25570  23754  The International Tree-Ring Data Bank (ITRDB) ...
#
#     DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0  TREE RING            7950               -65           -6000
#
#    MostRecentYearCE                                         StudyNotes  \
# 0              2015  Harmonized and corrected version of the ITRDB ...
#
#   ScienceKeywords                                      Investigators  \
# 0            None  Shoudong Zhao, Neil Pederson, Loïc D'Orangevil...
#
#                                         Publications  \
# 0  [{'Author': 'Shoudong Zhao, Neil Pederson, Loï...
#
#                                                Sites  \
# 0  [[{'DataTableID': '37493', 'DataTableName': 'Z...
#
#                                              Funding
# 0  [{'fundingAgency': 'National Science Foundatio...

# %% [markdown]
# next let's try to refine this a bit (not reconstructions, just raw data) then get the time index and filter to only include annual resolution.
# Or get all lake records from the WORLD that have data in the Common Era and plot their locations

# %%
ds_aus.get_sites()
# Out:
#   DataTableID DataTableName TimeUnit  \
# 0       37493      Zhao2018       CE
#
#                                              FileURL Variables  \
# 0  https://www.ncei.noaa.gov/pub/data/paleo/treer...        []
#
#   FileDescription  TotalFilesAvailable SiteID SiteName  \
# 0        Zip File                    1  22723   Global
#
#                LocationName Latitude Longitude MinElevation MaxElevation  \
# 0  Geographic Region>Global      -90        90         None         None
#
#   StudyID                                          StudyName
# 0   25570  The International Tree-Ring Data Bank (ITRDB) ...

# %%
ds_aus.get_tables()
# Out:
#   DataTableID DataTableName TimeUnit  \
# 0       37493      Zhao2018       CE
#
#                                              FileURL Variables  \
# 0  https://www.ncei.noaa.gov/pub/data/paleo/treer...        []
#
#   FileDescription  TotalFilesAvailable SiteID SiteName  \
# 0        Zip File                    1  22723   Global
#
#                LocationName Latitude Longitude MinElevation MaxElevation  \
# 0  Geographic Region>Global      -90        90         None         None
#
#   StudyID                                          StudyName
# 0   25570  The International Tree-Ring Data Bank (ITRDB) ...

# %%
ds_aus.get_sites()['FileURL'][0]
# Out:
# 'https://www.ncei.noaa.gov/pub/data/paleo/treering/measurements/zhao2018/AppendixS1.zip'

# %%
# returns an error because the table is a zip file
# ds_aus.get_data(dataTableIDs="37493")

# %%
ds_aus.get_geo()
# Out:
#   StudyID   DataType SiteID SiteName              LocationName Latitude  \
# 0   25570  TREE RING  22723   Global  Geographic Region>Global      -90
#
#   Longitude MinElevation MaxElevation
# 0        90         None         None

# %% [markdown]
# ### let's look for Australian lakes and plot their locations

# %%
aus_lakes_ds = Dataset()
aus_lakes_ds.search_studies(max_lat=-10, min_lat=-45, max_lon=160, min_lon=110, data_type_id=13)
# Out:
# Parsing NOAA studies: 100%|██████████████████| 21/21 [00:00<00:00, 2317.11it/s]
#    StudyID  XMLID                                          StudyName  \
# 0    12203  10267  2000 Year Precipitation-Based Southern Oscilla...
# 1    22315  20388        2000 Year Tropical Rainfall Reconstructions
# 2    22411  20588  Blue Lake, South Australia 6,000 Year Ostracod...
# 3    20452  18259  Duckhole Lake, Tasmania 950 Year Sediment Refl...
# 4    30799  72496  Eagle Tarn and Platypus Tarn Air Temperature R...
# 5    20529  18345                 Global Holocene Paleodust Database
# 6     5495    620  Global Lake-Level Variations from 18,000 to 0 ...
# 7    37158  78359  Lake Barrine, Australia TOC and Itrax Data Ove...
# 8    38232  79380  Lake Barrine, NE Australia brGDGT Data since 1...
# 9    22430  20598  Lake Keilambete, SE Australia Holocene Sedimen...
# 10   30660  72320  Lake Mackenzie, Subtropical East Australian Gl...
# 11   12336  10398  Lynch's Crater 45,000 Year Optical Absorption ...
# 12   22391  20516  Lynch's Crater, Australia Last Glacial Carbon ...
# 13    8407    674      NOAA Paleoclimatology Reconstructions Network
# 14   36134  77393  Paleo-pCO2 Database Global C3 Plant pCO2 Data ...
# 15   22416  20596  Rebecca Lagoon, Tasmania 3,700 Year Sediment R...
# 16   22432  20610  Southeast Australia 1,500 Year Crater Lake Sal...
# 17   22413  20590  Upper Snowy Mountains, Australia 6,500 Year Du...
# 18    5800   2481  Viau and Gajewski 2001 Global Lake Level Statu...
# 19   40679  81763  Western Pacific Warm Pool (WPWP) Precipitation...
# 20   22414  20592  Wimmera Lakes, Australia Holocene Ostracod Sal...
#
#                    DataType  EarliestYearBP  MostRecentYearBP  EarliestYearCE  \
# 0   CLIMATE RECONSTRUCTIONS          1900.0              -5.0            50.0
# 1   CLIMATE RECONSTRUCTIONS          2000.0             -50.0           -50.0
# 2            PALEOLIMNOLOGY          5690.0               5.0         -3740.0
# 3            PALEOLIMNOLOGY           883.0             -58.0          1067.0
# 4   CLIMATE RECONSTRUCTIONS         15862.0              29.0        -13912.0
# 5        LOESS AND PALEOSOL         12000.0               0.0        -10050.0
# 6               LAKE LEVELS         20000.0               0.0        -18050.0
# 7            PALEOLIMNOLOGY         18358.0            1445.0        -16408.0
# 8            PALEOLIMNOLOGY         18305.0             100.0        -16355.0
# 9            PALEOLIMNOLOGY          9550.0             -54.0         -7600.0
# 10  CLIMATE RECONSTRUCTIONS         37261.0             -48.0        -35311.0
# 11           PALEOLIMNOLOGY         45000.0               0.0        -43050.0
# 12           PALEOLIMNOLOGY         36059.0           22662.0        -34109.0
# 13  CLIMATE RECONSTRUCTIONS          1950.0             -50.0             0.0
# 14          CLIMATE FORCING         30000.0             -65.0        -28050.0
# 15           PALEOLIMNOLOGY          3654.0             -58.0         -1704.0
# 16           PALEOLIMNOLOGY          1472.0             -54.0           478.0
# 17           PALEOLIMNOLOGY          6493.0               3.0         -4543.0
# 18              LAKE LEVELS             NaN               NaN             NaN
# 19         PALEOCEANOGRAPHY        641300.0             -58.0       -639350.0
# 20           PALEOLIMNOLOGY         11394.0             -50.0         -9444.0
#
#     MostRecentYearCE                                         StudyNotes  \
# 0             1955.0  Reconstruction of a precipitation-based Southe...
# 1             2000.0  Composite reconstruction of low latitude rainf...
# 2             1945.0  Ostracod geochemical (Mg/Ca, Sr/Ca, Na/Ca) and...
# 3             2008.0  Sediment reflectance data (650-700 nm trough, ...
# 4             1921.0  This dataset was contributed as part of the Te...
# 5             1950.0  Mineral dust data (dust mass accumulation rate...
# 6             1950.0  Lake status determined at 1000-year intervals ...
# 7              505.0  Provided Keywords: northeastern Australia, bul...
# 8             1850.0  BrGDGTs from surface and downcore sediments in...
# 9             2004.0  Multiproxy Holocene sediment data and lake lev...
# 10            1998.0  This dataset was contributed as part of the Te...
# 11            1950.0  Optical absorption data from Lynch's Crater, Q...
# 12          -20712.0  Peat carbon content and pollen data for the la...
# 13            2000.0  NOAA Paleoclimatology Paleoclimate Network (PC...
# 14            2015.0                                               None
# 15            2008.0  Sediment reflectance data from Rebecca Lagoon,...
# 16            2004.0  Diatom modern-analougue technique salinity rec...
# 17            1947.0  Dust deposition rate from mire sediments colle...
# 18               NaN                                               None
# 19            2008.0  Provided Keywords: International Ocean Discove...
# 20            2000.0  Wimmera Lakes, Victoria, Australia Ostracod Ho...
#
#                                       ScienceKeywords  \
# 0   [Atmospheric and Oceanic Circulation Patterns ...
# 1                      [Precipitation Reconstruction]
# 2                                                None
# 3                    [Air Temperature Reconstruction]
# 4                    [Air Temperature Reconstruction]
# 5                                                None
# 6                                 [hydrology, trends]
# 7       [Younger Dryas, Precipitation Reconstruction]
# 8                                                None
# 9                                         [hydrology]
# 10                   [Air Temperature Reconstruction]
# 11                                        [hydrology]
# 12  [kauri pine, AGAU, Agathis australis (D. Don) ...
# 13                   [Air Temperature Reconstruction]
# 14                                               None
# 15                     [Precipitation Reconstruction]
# 16                                               None
# 17                                               None
# 18                                               None
# 19  [abrupt climate change, Tropics, Interglacial,...
# 20                                        [hydrology]
#
#                                         Investigators  \
# 0   Liguang Sun, Yuhong Wang, Wen Huang, Shican Qi...
# 1   Franziska Lechleitner, Sebastian Breitenbach, ...
# 2   Chris Gouramanis, Daniel Wilkins, Patrick De D...
# 3   Krystyna Saunders, Martin Grosjean, Dominic Ho...
# 4                             Andrew Rees, Les Cwynar
# 5                                       Samuel Albani
# 6   Frances Alayne Street-Perrott, None Marchand, ...
# 7                               Michael Bird, Ting Li
# 8                               Michael Bird, Ting Li
# 9   Daniel Wilkins, Patrick De Deckker, L. Keith F...
# 10  Martijn Woltering, Pia Atahan, Kliti Grice, He...
# 11  A. Peter Kershaw, Chris Turney, Steven Clemens...
# 12  Mark Grosvenor, Nicholas Golledge, Sune Rasmus...
# 13  Eugene Wahl, David Anderson, Bruce Bauer, Rodn...
# 14                        Brian Schubert, Hope Jahren
# 15  Krystyna Saunders, Christian Kamenik, Dominic ...
# 16  Cameron Barr, John Tibby, Peter Gell, Jonathan...
# 17  Samuel Marx, Balz Kamber, Hamish McGowan, John...
# 18                        Andre Viau, Konrad Gajewski
# 19         Samantha Bova, Yair Rosenthal, Xiaojing Du
# 20  Justine Kemp, Lynda Radke, Jon Olley, Steve Ju...
#
#                                          Publications  \
# 0   [{'Author': 'Yan, H., L. Sun, Y. Wang, W. Huan...
# 1   [{'Author': 'Franziska A. Lechleitner, Sebasti...
# 2   [{'Author': 'Chris Gouramanis, Daniel Wilkins,...
# 3   [{'Author': 'KM Saunders, M Grosjean, DA Hodgs...
# 4   [{'Author': 'Kaufman, D., McKay, N., Routson, ...
# 5   [{'Author': 'S. Albani, N.M. Mahowald, G. Winc...
# 6   [{'Author': 'Street-Perrott, F.A., D.S. Marcha...
# 7   [{'Author': 'Li, T., Wurster, C.M., Haig, J., ...
# 8   [{'Author': 'Li, Ting, Rainy Comley, Enlou Zha...
# 9   [{'Author': 'Daniel Wilkins, Chris Gouramanis,...
# 10  [{'Author': 'Kaufman, D., McKay, N., Routson, ...
# 11  [{'Author': 'Turney, C.S.M., A.P. Kershaw, S.C...
# 12  [{'Author': 'Chris S.M. Turney, Richard T. Jon...
# 13  [{'Author': 'Wahl, E.R., D.M. Anderson, B.A. B...
# 14  [{'Author': 'Schubert, B. A., and Jahren, A. H...
# 15  [{'Author': 'Saunders, K.M.; Kamenik, C.; Hodg...
# 16  [{'Author': 'Jonathan J. Tyler, Keely Mills, C...
# 17  [{'Author': 'Samuel K. Marx, Balz S. Kamber, H...
# 18  [{'Author': 'Viau, A.E. and K. Gajewski', 'Tit...
# 19  [{'Author': 'Bova, S.C., Y. Rosenthal, and X. ...
# 20  [{'Author': 'Justine Kemp, Lynda C. Radke, Jon...
#
#                                                 Sites  \
# 0   [[{'DataTableID': '20526', 'DataTableName': 'S...
# 1   [[{'DataTableID': '33444', 'DataTableName': 'L...
# 2   [[{'DataTableID': '33534', 'DataTableName': 'B...
# 3   [[{'DataTableID': '31156', 'DataTableName': 'D...
# 4   [[{'DataTableID': '43353', 'DataTableName': 'E...
# 5   [[{'DataTableID': '31279', 'DataTableName': 'A...
# 6   [[{'DataTableID': '8788', 'DataTableName': 'Ab...
# 7   [[{'DataTableID': '49839', 'DataTableName': 'B...
# 8   [[{'DataTableID': '50805', 'DataTableName': 'B...
# 9   [[{'DataTableID': '33555', 'DataTableName': 'K...
# 10  [[{'DataTableID': '43343', 'DataTableName': 'M...
# 11  [[{'DataTableID': '20678', 'DataTableName': 'L...
# 12  [[{'DataTableID': '33507', 'DataTableName': 'L...
# 13  [[{'DataTableID': '20557', 'DataTableName': 'P...
# 14  [[{'DataTableID': '48778', 'DataTableName': 'c...
# 15  [[{'DataTableID': '33547', 'DataTableName': 'R...
# 16  [[{'DataTableID': '33564', 'DataTableName': 'S...
# 17  [[{'DataTableID': '33535', 'DataTableName': 'S...
# 18  [[{'DataTableID': 'Unspecified', 'DataTableNam...
# 19  [[{'DataTableID': '55420', 'DataTableName': 'I...
# 20  [[{'DataTableID': '33544', 'DataTableName': 'J...
#
#                                               Funding
# 0   [{'fundingAgency': 'National Natural Science F...
# 1   [{'fundingAgency': 'European Union', 'fundingG...
# 2                                                  []
# 3   [{'fundingAgency': 'European Union', 'fundingG...
# 4                                                  []
# 5   [{'fundingAgency': 'US National Science Founda...
# 6                                                  []
# 7   [{'fundingAgency': 'Australian Research Counci...
# 8   [{'fundingAgency': 'Australian Research Counci...
# 9   [{'fundingAgency': 'Australian Research Counci...
# 10                                                 []
# 11  [{'fundingAgency': 'UK Natural Environment Res...
# 12  [{'fundingAgency': 'UK Natural Environment Res...
# 13                                                 []
# 14  [{'fundingAgency': 'US Department of Energy', ...
# 15  [{'fundingAgency': 'Marie Curie Fellowship', '...
# 16  [{'fundingAgency': 'Australian Nuclear Science...
# 17  [{'fundingAgency': 'Australian Research Counci...
# 18                                                 []
# 19  [{'fundingAgency': 'US National Science Founda...
# 20                                                 []

# %%
lakes_geo = aus_lakes_ds.get_geo()
lakes_geo.keys()
# Out:
# Index(['StudyID', 'DataType', 'SiteID', 'SiteName', 'LocationName', 'Latitude',
#        'Longitude', 'MinElevation', 'MaxElevation'],
#       dtype='object')

# %%
lakes_dat = aus_lakes_ds.get_tables()
lakes_dat.keys()
# Out:
# Index(['DataTableID', 'DataTableName', 'TimeUnit', 'FileURL', 'Variables',
#        'FileDescription', 'TotalFilesAvailable', 'SiteID', 'SiteName',
#        'LocationName', 'Latitude', 'Longitude', 'MinElevation', 'MaxElevation',
#        'StudyID', 'StudyName'],
#       dtype='object')

# %%
# here ar ethe unique site names - definitely not all in Australia
print(set(lakes_dat['SiteName']))
# Out:
# {'Makgadikgadi', 'Leconte', 'Mundafan, Rub Al-Khali', 'Jacob', 'Kunteyi', 'Zawiyah', 'Erg Ine Sakane 57-19', 'El Rharsa', 'Katwe', 'Serir', 'Nefud-Urayq', 'Walker', 'Mound', 'Chiu-Chiu', 'Abu Tartur', 'Griqualand', 'Jebel Marra (Deriba)', 'Rukwa', 'Pityoulish', 'Suguta Valley', 'Kufra', 'Tagnout-Chaggaret', 'Frome', 'Etosha', 'Chichancanab', 'Willandra', 'La Guitarra', 'Ine Kousamene', 'Nakuru-Elmenteita', 'Rich', 'Ngami-Mababe', 'Kafra-Achegour', 'Chalbi', 'Rutz', 'Oukechert', 'Harney-Malheur', 'Turkana', 'Gebel Maghara', 'Seguedine', 'Tritrivakely', 'Arch', 'Ioannina', 'Upper Lerma Basin', 'Dibella', 'Swan', 'Okoboji', 'Carp', 'Chew Bahir', 'Rock Basin', 'Lisan-Dead Sea', 'Oum Arouaba', 'Bouloum Gana', 'Tamaya Mellet', 'Badr', 'Bromfield', 'Begour', 'Wallywash', 'Hook', 'En Nahud', 'Monahans Dunes', 'Elk Lake - North', 'Howar', 'Duck', 'Pickerel', 'Zuni', 'Alexandersfontein', 'Laguna Salada', 'Wyrie', 'Bushmans Fountain', 'In Aridal', 'Besaka', 'Mentes', 'Storeys', 'Afrera', 'Balaton', 'Zoo Baba', 'Bir Tarfawi-Bir Sahara', 'Goshen', 'Lop Nor', 'Wedge', 'Bullenmerri', 'Urmia', 'Beysehir', 'Merga', 'Lake Mobutu Sese Seko', 'Pulbeena', 'Breek Been Kolk', 'Quincan', 'Erg Ine Sakane', 'Tagua Tagua', 'Ziway-Shala', 'Herrera', 'Saoura', "Lynch's Crater", 'White', 'Tropics', 'Daiet el Melah', 'Liebenbergspan', 'Oyo', 'Guthrie', 'Dayet Aaoua', 'Cochise', 'Lake Victoria', 'Quexil', 'Szabo', 'Irzerzou', 'Cahaba', 'Victoria', 'Klein Awas', 'Waldsea', 'Urwi', 'Eagle Tarn', 'Zharinanmuco', 'Tyotjarvi', 'Maine-Soroa', 'Issyk-Kul', 'Tabuk', 'Hirafok', 'Bou Ali', 'Lunkaransar', 'ElAtrun', 'Fiddlers', 'Zhangzang Chaka', 'Qarat El Howeit', 'Lake Keilambete', 'El Abra', 'Deep Spring', 'Hastings', 'Fort Rock', 'Marshes', 'Tauca', 'Mission Cross', 'Tigalmamine', 'Tarso Yega', 'Lynchs Crater', 'Murzuk (Anai)', 'Warner Valley', 'Dawasir', 'Kharga', 'Wanum', 'Selima', 'Kow', 'Ard El Akhdar', 'Patzcuaro', 'Blue Lake SA', 'Clovis', 'IODP U1485', 'Koichab', 'Diamond', 'Myalup', 'Hassi el Mejna', 'Mojave', 'Palmyra', 'Jebel Quoquin', 'Isle', 'Western Pacific Warm Pool', 'Kirchner', 'Haijad', 'Da Qaidam', 'Qinghai', 'Annie', 'Al-Hasa', 'Tin Guettai', 'Murzuk (Achelouma)', 'San Agustin', 'Tiberias', 'Tirersioum', 'Chenco', 'Chalmers', 'Tarada', 'Eyasi', 'Abhe', 'Lake Chad', 'Manix', 'Teel', 'Adobe', 'Kivu', 'Gnotuk', 'Little Salt', 'Hora', 'Ciega', 'Keilambete', 'Konya', 'Tassara', 'Valley', 'Magad', 'Nabta', 'Lahontan', 'Albacutya', 'Ben Chora', 'Van', 'Trou Au Natron', 'Alsacia', 'Termit Ouest-Kandel Bouzou', 'Nadquan', 'Browns', 'Corangamite', 'Tageru', 'Cobrico', 'Sbeita', 'Lake Mackenzie', 'Poukawa', 'Lake Surprise', 'Kepa', 'Kadda', 'An-Nafud', 'Beatties', 'Erg Jmeya', 'Hassi el Abiod', 'Chewaucan', 'King', 'Naivasha', 'Rub Al-Khali', 'Fucino', 'Smallboy', 'Lubbock', 'Bou Bernous', 'Aozerkat', 'Bogoria', 'Cari Laufquen Grande', 'Chilwa', 'Whitneys Gulch', 'Rotorua', 'Finlayson', 'Rhiz', 'Damascus', 'Sambhar', 'Comarum So', 'El Gobernador', 'Manapouri', 'Bosumtwi', 'Murzuk (El-Gatrun)', 'Lake Titicaca', 'Ruby', 'Euramoo', 'Mellala', 'Clark', 'Salt', 'Leake', 'Hassei Gaboun', 'Haaskraal', 'Chiconahuapan', 'Hassi Messouad', 'Platypus Tarn', 'Panamint', 'Manyara', 'Manly', 'Tyrrell', 'Wabamun', 'Tysons', 'Upper Snowy Mountains', 'Didwana', 'Rosebud', 'Estancia', 'Kandahar', 'Feshfesh', 'Wielkie Gacno', 'Weber', 'Grace', 'El Jafr', 'Wonchi', 'Lake Barrine', 'Enneri Bardague', 'Colongulac', 'Tahoe', 'Asal', 'Bahariya', 'Khat', 'Ichourad', 'Gawane', 'Ghadames', 'Lake Tanganyika', 'Baringo', 'Seistan', 'Tulare', 'Adrar Bous', 'Hussein', 'Bilma', 'Dobi-Hanle', 'Russell', 'Rebecca Lagoon', 'Kettle Hole', 'Burdur', 'Bancannia', 'Ounianga Kebir', 'Devils', 'Hassi Cheikh', 'Lake Elingamite', 'Wintergreen', 'Salpeten', 'Chemchane-Aderg', 'Crown', 'Moore', 'Hay', 'Valencia', 'Global', 'Fderick (Fort-Gouraud)', 'Tsondab', 'Eagle - Tasmania', 'Eyre', 'Elk Island', 'Azawagh', 'Buenos Aires', 'Taoudenni', 'Shaw-Sahl', 'El Junco', 'Bonneville', 'Erg Ine Sakane 48-50',  ...

# %%
# filter the lakes_geo object to only keep lats/lons in Australia
# actually no - do this straight on the lakes_dat object, which also has lat and lon
minlat = -45
maxlat = -10
minlon = 110
maxlon = 160

# convert to df
lakes_dat_df = pd.DataFrame(lakes_dat)

# these are stored as strings
lakes_dat_df['Latitude'] = pd.to_numeric(lakes_dat_df['Latitude'], errors='coerce')
lakes_dat_df['Longitude'] = pd.to_numeric(lakes_dat_df['Longitude'], errors='coerce')

lakes_dat_df = lakes_dat_df[
    (lakes_dat_df['Latitude'] >= minlat) & (lakes_dat_df['Latitude'] <= maxlat) &
    (lakes_dat_df['Longitude'] >= minlon) & (lakes_dat_df['Longitude'] <= maxlon)
]

### ok do the same for the geo info - maybe we'll need it?
# convert to df
lakes_geo_df = pd.DataFrame(lakes_geo)

# these are stored as strings
lakes_geo_df['Latitude'] = pd.to_numeric(lakes_geo_df['Latitude'], errors='coerce')
lakes_geo_df['Longitude'] = pd.to_numeric(lakes_geo_df['Longitude'], errors='coerce')

lakes_geo_df = lakes_geo_df[
    (lakes_geo_df['Latitude'] >= minlat) & (lakes_geo_df['Latitude'] <= maxlat) &
    (lakes_geo_df['Longitude'] >= minlon) & (lakes_geo_df['Longitude'] <= maxlon)
]

# %%
# and the individual sites
lake_sites = aus_lakes_ds.get_sites()
lake_sites_df = pd.DataFrame(lake_sites)

print(lakes_dat_df.shape)
print(lakes_geo_df.shape)
print(lake_sites_df.shape)
# Out:
# (345, 16)
# (52, 9)
# (2908, 16)

# %%
# now filter the data summary to match (I could have done this directly on the lakes_dat object!! because it has lat and lon)
lakes_sum = aus_lakes_ds.get_summary()
lakes_sum_df = pd.DataFrame(lakes_sum)

studyIDs = set(lakes_dat_df['StudyID'])

# filter to match the Australia-only lakes (filtering on site name)
lakes_sum_df = lakes_sum_df[lakes_sum_df['StudyID'].isin(studyIDs)]

# same with the site df
siteIDs = set(lakes_dat_df['SiteID'])
lake_sites_df = lake_sites_df[lake_sites_df['SiteID'].isin(siteIDs)]

# %%
print(lakes_sum_df.shape)
print(lake_sites_df.shape)
# Out:
# (14, 14)
# (345, 16)

# %%
# add the record length information from the study summary to the data tables
# note that the lengths may not match the specific lengths of the actual records - these are from the *study* metadata
# a better way would be to read in the data table and extract the age column. But that would be...finicky. Unless it's always in the same place. 
# and there are issues with CE versus BP
# and certain rows don't seem to work e.g., index 11

# first, only keep unique instances of site name
unique_lakes = lake_sites_df.drop_duplicates(subset='SiteName', keep='first')
print(f"this many unique lakes: {unique_lakes.shape[0]}")

# now add length in the Common Era
lakes_sum_df['EarliestYearCE'] = pd.to_numeric(lakes_sum_df['EarliestYearCE'], errors='coerce')
lakes_sum_df['MostRecentYearCE'] = pd.to_numeric(lakes_sum_df['MostRecentYearCE'], errors='coerce')

# time info
time_info = lakes_sum_df[['EarliestYearCE', 'MostRecentYearCE', 'StudyID']]
time_info['EarliestYearCE'] = time_info['EarliestYearCE'].apply(lambda x: max(x, 0)) # replace pre-CE years with 0
time_info['length'] = time_info['MostRecentYearCE'] - time_info['EarliestYearCE']

# add to the unique lakes df
unique_lakes = unique_lakes.merge(time_info, on='StudyID', how='left')
# Out:
# this many unique lakes: 50
# C:\Users\georg\AppData\Local\Temp\ipykernel_37000\2742128480.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_info['EarliestYearCE'] = time_info['EarliestYearCE'].apply(lambda x: max(x, 0)) # replace pre-CE years with 0
# C:\Users\georg\AppData\Local\Temp\ipykernel_37000\2742128480.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_info['length'] = time_info['MostRecentYearCE'] - time_info['EarliestYearCE']

# %%
# some tidying - several of these are no longer accurate as the rows aren't linked to specific data tables
unique_lakes = unique_lakes[['SiteID', 'SiteName', 'Latitude', 'Longitude', 'MinElevation', 'MaxElevation', 'StudyID', 'StudyName', 'EarliestYearCE', 'MostRecentYearCE', 'length']]
unique_lakes['MinElevation'] = pd.to_numeric(unique_lakes['MinElevation'], errors='coerce')
unique_lakes['MaxElevation'] = pd.to_numeric(unique_lakes['MaxElevation'], errors='coerce')

unique_lakes['Latitude'] = pd.to_numeric(unique_lakes['Latitude'], errors='coerce')
unique_lakes['Longitude'] = pd.to_numeric(unique_lakes['Longitude'], errors='coerce')

# %% [markdown]
# I'd like to have coloured these by elevation but the elvation is recorded at study level - so they're basically all the same (and don't refelct the actual lake locations)

# %%
# now plot the lake locations

# get Australia outline
shpfilename = natural_earth(resolution='10m', category='cultural', name='admin_0_countries')
reader = Reader(shpfilename)
australia_geom = [record.geometry for record in reader.records()
                  if record.attributes['NAME_LONG'] == 'Australia']

def plot_sites(row, col, site_dat, dat_proj, new_proj, title, vmin, vmax,
                    cmap="RdBu", size_scale=15, show_title=True):
    
    ax = fig.add_subplot(gs[row, col], projection=new_proj)

    ax.set_extent([110, 155, -45, -10], crs=ccrs.PlateCarree())

    # Draw Australia
    ax.add_geometries(australia_geom, crs=ccrs.PlateCarree(),
                      edgecolor='black', facecolor='none', linewidth=0.5)

    # Overlay points
    norm = mcolors.Normalize(vmin=vmin, vmax=vmax)
    cmap_instance = cm.get_cmap(cmap)
    sizes = np.sqrt(site_dat['length']) * size_scale
    sc = ax.scatter(site_dat['Longitude'], site_dat['Latitude'], c=site_dat['length'],
                    cmap=cmap_instance, norm=norm, transform=dat_proj,
                    edgecolor='k', s=sizes)

    if show_title:
        ax.set_title(title, fontname='Arial', color='black', fontsize=14)

    ax.axis('off')

    return sc

# %%
fig = plt.figure(figsize=(6, 6))
gs = gridspec.GridSpec(1, 2, width_ratios=[1,0.06], wspace=0.2)

dat_proj = new_proj = ccrs.PlateCarree()
cmap = "bone"

mpl.rcParams['font.family'] = 'Arial'
mpl.rcParams['text.color'] = 'black'
mpl.rcParams['axes.labelcolor'] = 'black'
mpl.rcParams['xtick.color'] = 'black'
mpl.rcParams['ytick.color'] = 'black'

vmin = 500
vmax = 2000

title = "Lake records from NOAA"
label = "Dataset length in CE\n(years)"

im = plot_sites(0, 0, unique_lakes, dat_proj, new_proj, title, vmin, vmax, cmap=cmap, size_scale=3, show_title=True)

cax = fig.add_subplot(gs[0, 1])
pos = cax.get_position()
cax.set_position([pos.x0, pos.y0 + 0.1, pos.width, pos.height * 0.7]) 
cbar = fig.colorbar(im, cax=cax, extend='both')
cbar.set_label(label, fontsize=12)
# Out:
# C:\Users\georg\AppData\Local\Temp\ipykernel_37000\2572418359.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap_instance = cm.get_cmap(cmap)
